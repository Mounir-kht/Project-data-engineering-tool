# %%
pip install scrapy

# %%
import scrapy
import requests

# %%
# !scrapy runspider RedditSpider.py
# Out:
# 2023-01-10 16:36:59 [scrapy.utils.log] INFO: Scrapy 2.7.1 started (bot: scrapybot)
# 2023-01-10 16:36:59 [scrapy.utils.log] INFO: Versions: lxml 4.6.3.0, libxml2 2.9.12, cssselect 1.2.0, parsel 1.7.0, w3lib 2.0.1, Twisted 22.10.0, Python 3.9.7 (default, Sep 16 2021, 08:50:36) - [Clang 10.0.0 ], pyOpenSSL 21.0.0 (OpenSSL 1.1.1l  24 Aug 2021), cryptography 3.4.8, Platform macOS-10.16-x86_64-i386-64bit
# 2023-01-10 16:36:59 [scrapy.crawler] INFO: Overridden settings:
# {'SPIDER_LOADER_WARN_ONLY': True}
# 2023-01-10 16:36:59 [py.warnings] WARNING: /Users/Arthur1/opt/anaconda3/lib/python3.9/site-packages/scrapy/utils/request.py:231: ScrapyDeprecationWarning: '2.6' is a deprecated value for the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting.
#
# ...

# %%
res = scrap.parse(response)
res
# Out:
# <generator object RedditSpider.parse at 0x7f9ced2bd190>
